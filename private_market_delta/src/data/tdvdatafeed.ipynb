# %%
from tvDatafeed import TvDatafeed, Interval

# %%
username = 'spinsnake'
password = 'YxK7c,7S7/6gp'

tv = TvDatafeed(username, password)

# %%
tv.search_symbol('GC')
# Out:
# [{'symbol': 'GC',
#   'description': 'GOLD FUTURES',
#   'type': 'futures',
#   'exchange': 'COMEX',
#   'currency_code': 'USD',
#   'logoid': 'metal/gold',
#   'provider_id': 'ice',
#   'country': 'US',
#   'contracts': [{'symbol': 'GC1!', 'typespecs': ['continuous', 'synthetic']},
#    {'symbol': 'GC2!', 'typespecs': ['continuous', 'synthetic']},
#    {'symbol': 'GCZ2023', 'description': 'DEC 2023'},
#    {'symbol': 'GCF2024', 'description': 'JAN 2024'},
#    {'symbol': 'GCG2024', 'description': 'FEB 2024'},
#    {'symbol': 'GCJ2024', 'description': 'APR 2024'},
#    {'symbol': 'GCM2024', 'description': 'JUN 2024'},
#    {'symbol': 'GCQ2024', 'description': 'AUG 2024'},
#    {'symbol': 'GCV2024', 'description': 'OCT 2024'},
#    {'symbol': 'GCZ2024', 'description': 'DEC 2024'},
#    {'symbol': 'GCG2025', 'description': 'FEB 2025'},
#    {'symbol': 'GCJ2025', 'description': 'APR 2025'},
#    {'symbol': 'GCM2025', 'description': 'JUN 2025'},
# ...

# %%
GC_data = tv.get_hist(symbol='GC',exchange='COMEX',interval=Interval.in_1_hour,n_bars=1000,fut_contract=1)

# %%
GC_data
# Out:
#                          symbol    open    high     low   close   volume
# datetime
# 2023-10-03 05:00:00  COMEX:GC1!  1844.9  1845.3  1843.4  1844.0   2266.0
# 2023-10-03 06:00:00  COMEX:GC1!  1843.9  1844.1  1836.4  1841.0   6935.0
# 2023-10-03 07:00:00  COMEX:GC1!  1840.9  1841.2  1838.0  1840.6   3698.0
# 2023-10-03 08:00:00  COMEX:GC1!  1840.5  1841.0  1838.4  1838.6   2676.0
# 2023-10-03 09:00:00  COMEX:GC1!  1838.7  1839.0  1830.9  1833.0   7183.0
# ...                         ...     ...     ...     ...     ...      ...
# 2023-12-01 17:00:00  COMEX:GC1!  2066.2  2067.0  2062.7  2063.3   3760.0
# 2023-12-01 18:00:00  COMEX:GC1!  2063.3  2063.8  2055.7  2056.4   7789.0
# 2023-12-01 19:00:00  COMEX:GC1!  2056.4  2057.9  2052.6  2055.3   7746.0
# 2023-12-01 20:00:00  COMEX:GC1!  2055.2  2058.7  2054.3  2057.0  10301.0
# 2023-12-01 21:00:00  COMEX:GC1!  2057.0  2057.9  2054.7  2055.4   1623.0
#
# [1000 rows x 6 columns]
